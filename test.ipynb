# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
# %matplotlib ipympl

# %%
test = np.load('./data/03001627_inputRGB/1006be65e7bc937e9141f9b58470d646.npy') / 255.0
print(test.shape)
print(test[0].shape)
test_image = test[14]
# Out:
# (24, 64, 64, 3)
# (64, 64, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot()

plt.imshow(test_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#mat_import = scipy.io.loadmat("./data/03001627_depth/1006be65e7bc937e9141f9b58470d646.mat")
mat_import = scipy.io.loadmat("./data/03001627_depth_fixed8/1006be65e7bc937e9141f9b58470d646.mat")

# %%
print(mat_import.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Z'])

# %%
print(mat_import["Z"].shape)
# Out:
# (8, 128, 128)

# %%
print(mat_import["Z"][0].shape)
# Out:
# (128, 128)

# %%
mat = mat_import["Z"][0]
test_array= np.array(mat)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mat_import = scipy.io.loadmat("./results/ORIG_STG2_sgd_trueWD_adam_trueWD_1K/108238b535eb293cd79b19c7c4f0e293.mat")
#108238b535eb293cd79b19c7c4f0e293.mat ok
#1ac6531a337de85f2f7628d6bf38bcc4.mat yikes
#11e28120789c20abc8687ff9b0b4e4ac.mat perfect 
print(mat_import.keys())
print( "image shape " , mat_import["image"].shape)
print("image 0 shape " , mat_import["image"][0].shape)
print("pointcloud shape ",mat_import["pointcloud"].shape)

mat = mat_import["image"][0]
test_array= np.array(mat)

fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'image', 'pointcloud'])
# image shape  (24, 64, 64, 3)
# image 0 shape  (64, 64, 3)
# pointcloud shape  (24, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(mat_import["pointcloud"])
print(mat_import["pointcloud"].shape)
# Out:
# [[array([[-0.12540764, -0.19353148,  0.21245944],
#          [-0.12503412, -0.19275951,  0.20776911],
#          [-0.1236462 , -0.19215912,  0.20320009],
#          ...,
#          [-0.27370378,  0.15547115,  0.35167354],
#          [-0.26249242,  0.15368824,  0.35011286],
#          [-0.26822037,  0.15578535,  0.35455334]], dtype=float32)]
#  [array([[ 0.18908139,  0.37679425,  0.2649861 ],
#          [ 0.18831545,  0.37879276,  0.26557314],
#          [ 0.18830281,  0.37975025,  0.26521915],
#          ...,
#          [-0.16204089,  0.07320216,  0.19874905],
#          [-0.16012877,  0.07500316,  0.19688506],
#          [-0.1591245 ,  0.0779051 ,  0.19486177]], dtype=float32)]
#  [array([[ 0.19405279,  0.38690427,  0.26348573],
#          [ 0.19332144,  0.38884768,  0.2636778 ],
#          [ 0.19249517,  0.3900228 ,  0.2637618 ],
#          ...,
#          [-0.16730073,  0.08301219,  0.20045498],
#          [-0.16422325,  0.08598049,  0.19978668],
#          [-0.16234088,  0.08728048,  0.19696268]], dtype=float32)]
#  [array([[ 0.19226366,  0.3899436 ,  0.26425403],
#          [ 0.19130272,  0.3915341 ,  0.2639668 ],
#          [ 0.19828288,  0.36856806,  0.2628039 ],
#          ...,
#          [-0.16142476,  0.08587708,  0.19520766],
#          [-0.15840366,  0.08762323,  0.19503164],
#          [-0.15656683,  0.08880591,  0.1937874 ]], dtype=float32)]
#  [array([[ 0.18910097,  0.37690324,  0.26513755],
#          [ 0.18832046,  0.37892148,  0.26573867],
#          [ 0.18830304,  0.37988073,  0.26538318],
#          ...,
#          [-0.16221315,  0.07323123,  0.1991866 ],
#          [-0.16031775,  0.07502721,  0.19734862],
#          [-0.1593385 ,  0.07795574,  0.19537956]], dtype=float32)]
#  [array([[ 0.0020283 , -0.27357805,  0.08341897],
#          [ 0.00235269, -0.27100047,  0.07894665],
#          [ 0.00325883, -0.26735362,  0.07561317],
#          ...,
#          [-0.31115752,  0.1342151 ,  0.30133292],
#          [-0.30923846,  0.13767843,  0.3055026 ],
#          [-0.3091147 ,  0.14000726,  0.30515623]], dtype=float32)]
#  [array([[-1.4903992e-03, -2.7112478e-01,  8.7836266e-02],
#          [-9.0736151e-04, -2.6860237e-01,  8.3455205e-02],
#          [-2.8885156e-04, -2.6572141e-01,  7.9082698e-02],
#          ...,
#          [-3.0904686e-01,  1.3745421e-01,  3.0534691e-01],
#          [-3.0892462e-01,  1.3979581e-01,  3.0500293e-01],
#          [-3.0719489e-01,  1.4251223e-01,  3.0931002e-01]], dtype=float32)]
#  [array([[-1.9960105e-03, -2.6347575e-01,  8.3435446e-02],
#          [-1.1105165e-03, -2.6054507e-01,  7.9013497e-02],
#          [ 8.6940825e-05, -2.5688159e-01,  7.5690359e-02],
#          ...,
#          [-3.0212420e-01,  1.4945976e-01,  3.1496578e-01],
#          [-3.1050700e-01,  1.3491395e-01,  3.0189845e-01],
#          [-3.0883652e-01,  1.4044565e-01,  3.0527741e-01]], dtype=float32)]
#  [array([[ 0.07909229, -0.24147588,  0.15620798],
#          [ 0.07848585, -0.23735023,  0.15483683],
#          [ 0.08144134, -0.23810533,  0.16013944],
#          ...,
#          [-0.25389233,  0.14702548,  0.33865243],
#          [-0.25996122,  0.14898375,  0.34295672],
#          [-0.26631463,  0.15160212,  0.34604055]], dtype=float32)]
#  [array([[ 0.09917721, -0.24784097,  0.18598552],
#          [ 0.08672799, -0.24617422,  0.16619937],
#          [ 0.09393328, -0.24644512,  0.18037827],
#          ...,
#          [-0.24952267,  0.14577007,  0.3378027 ],
#          [-0.2540002 ,  0.14728534,  0.33912128],
#          [-0.26009858,  0.14924188,  0.34343284]], dtype=float32)]
#  [array([[ 0.09148571, -0.2484628 ,  0.1720508 ],
#          [ 0.09517065, -0.24689326,  0.17798293],
#          [ 0.09889432, -0.24751407,  0.18615805],
#          ...,
#          [-0.306671  ,  0.13808884,  0.30090392],
#          [-0.3050057 ,  0.14052439,  0.3046151 ],
#          [-0.30498487,  0.14288048,  0.30682617]], dtype=float32)]
#  [array([[ 0.08254541, -0.24177551,  0.16274923],
#          [ 0.08599802, -0.24096984,  0.1684466 ],
#          [ 0.07414245, -0.2410407 ,  0.15076196],
#          ...,
#          [-0.31133682,  0.13417059,  0.3012883 ],
#          [-0.30916798,  0.13768968,  0.30565524],
#          [-0.30916333,  0.14010578,  0.30552834]], dtype=float32)]
#  [array([[ 0.1139906 , -0.26133254,  0.20434003],
#          [ 0.11618835, -0.26083305,  0.20919   ],
#          [ 0.11747028, -0.26176268,  0.2133098 ],
#          ...,
#          [-0.311902  ,  0.13494882,  0.30204442],
#          [-0.30995646,  0.13839453,  0.30631217],
#          [-0.30984402,  0.14068876,  0.30603623]], dtype=float32)]
#  [array([[ 0.09131497, -0.24817291,  0.17255017],
#          [ 0.09498087, -0.24653697,  0.17847875],
#          [ 0.0986662 , -0.24707219,  0.18665436],
#          ...,
#          [-0.30325046,  0.14711954,  0.31424606],
#          [-0.3027295 ,  0.14983314,  0.31603384],
#          [-0.30937093,  0.14085945,  0.30613965]], dtype=float32)]
#  [array([[-2.4763197e-03, -2.5747961e-01,  8.5372597e-02],
#          [-1.1939853e-03, -2.5429019e-01,  8.1073761e-02],
#          [ 2.0032376e-04, -2.5069737e-01,  7.7716202e-02],
#          ...,
#          [-3.0198830e-01,  1.4934094e-01,  3.1474400e-01],
#          [-3.1035140e-01,  1.3475807e-01,  3.0169204e-01],
#          [-3.0868685e-01,  1.4030722e-01,  3.0505535e-01]], dtype=float32)]
#  [array([[-0.00746713, -0.24950182,  0.08585641],
#          [-0.00359391, -0.24281695,  0.07821873],
#          [-0.00900847, -0.24742156,  0.10446653],
#          ...,
#          [-0.31055433,  0.13427444,  0.30128962],
#          [-0.3088652 ,  0.13767216,  0.3052904 ],
#          [-0.30872267,  0.13993901,  0.30478954]], dtype=float32)]
#  [array([[-0.0088338 , -0.24110404,  0.10730174],
#          [-0.00847583, -0.24032241,  0.10121298],
#          [-0.0073704 , -0.23817575,  0.0967637 ],
#          ...,
#          [-0.3088231 ,  0.13740772,  0.30515212],
#          [-0.30867305,  0.13968468,  0.30467975],
#          [-0.30687773,  0.14231996,  0.3088422 ]], dtype=float32)]
#  [array([[-0.00354089, -0.26624152,  0.08751062],
#          [-0.00274972, -0.26370025,  0.08307171],
#          [-0.00187519, -0.26074857,  0.07869184],
#          ...,
#          [-0.30898932,  0.13738169,  0.30530164],
#          [-0.30886033,  0.13971546,  0.30493867],
#          [-0.3071208 ,  0.14242077,  0.3092228 ]], dtype=float32)]
#  [array([[-3.7804991e-04, -2.6845407e-01,  8.3620667e-02],
#          [ 2.3414940e-04, -2.6559979e-01,  7.9213083e-02],
#          [ 1.2823120e-03, -2.6189998e-01,  7.5896680e-02],
#          ...,
#          [-3.1090397e-01,  1.3446824e-01,  3.0144528e-01],
#          [-3.0915627e-01,  1.3786802e-01,  3.0548722e-01],
#          [-3.0901545e-01,  1.4014298e-01,  3.0503267e-01]], dtype=float32)]
#  [array([[ 0.08331052, -0.24266213,  0.16201422],
#          [ 0.08680412, -0.24210599,  0.16774203],
#          [ 0.07869216, -0.24087265,  0.15662284],
#          ...,
#          [-0.3067886 ,  0.13782549,  0.30038387],
#          [-0.30511117,  0.14029376,  0.30415154],
#          [-0.30512625,  0.14265786,  0.30638376]], dtype=float32)]
#  [array([[ 0.07897191, -0.24156699,  0.1566562 ],
#          [ 0.07824697, -0.23748401,  0.15523577],
#          [ 0.08120824, -0.23824742,  0.16051967],
#          ...,
#          [-0.26107353,  0.15230595,  0.34842795],
#          [-0.26677054,  0.15440625,  0.3528393 ],
#          [-0.27291882,  0.15710759,  0.3559726 ]], dtype=float32)]
#  [array([[-0.12950714, -0.20582011,  0.21205638],
#          [-0.12914091, -0.20532003,  0.20743717],
#          [-0.12761524, -0.2051138 ,  0.20265476],
#          ...,
#          [-0.2537536 ,  0.14656465,  0.33820692],
#          [-0.2597673 ,  0.14853366,  0.34250388],
#          [-0.2660698 ,  0.15114681,  0.34556183]], dtype=float32)]
#  [array([[-0.11380378, -0.17247105,  0.21305417],
#          [-0.11402301, -0.17093912,  0.20801798],
#          [-0.11332002, -0.16923678,  0.20329398],
#          ...,
#          [-0.2750487 ,  0.15712555,  0.35645354],
#          [-0.2807936 ,  0.16110656,  0.3614921 ],
#          [-0.28433204,  0.16307342,  0.3612355 ]], dtype=float32)]
#  [array([[-0.11727374, -0.17686611,  0.21358018],
#          [-0.11724924, -0.17540482,  0.20860805],
#          [-0.11627185, -0.1738007 ,  0.20396408],
#          ...,
#          [-0.30565286,  0.13782652,  0.29974294],
#          [-0.3040538 ,  0.14015472,  0.30327326],
#          [-0.30407536,  0.14241862,  0.30528992]], dtype=float32)]]
# (24, 1)

# %%
print(mat_import["pointcloud"][0].shape)
print(mat_import["pointcloud"][0])
# Out:
# (1,)
# [array([[-0.12540764, -0.19353148,  0.21245944],
#         [-0.12503412, -0.19275951,  0.20776911],
#         [-0.1236462 , -0.19215912,  0.20320009],
#         ...,
#         [-0.27370378,  0.15547115,  0.35167354],
#         [-0.26249242,  0.15368824,  0.35011286],
#         [-0.26822037,  0.15578535,  0.35455334]], dtype=float32)]

# %%
print(mat_import["pointcloud"][0][0].shape)
print(mat_import["pointcloud"][0][0])


mat = mat_import["pointcloud"][0]
print(mat)
# Out:
# (11575, 3)
# [[-0.00154179 -0.27406773  0.09698609]
#  [-0.00104215 -0.27246043  0.0919264 ]
#  [-0.00216231 -0.27137497  0.0866614 ]
#  ...
#  [-0.30914643  0.13757195  0.30538505]
#  [-0.30904537  0.1399334   0.30508766]
#  [-0.30734476  0.14267413  0.30945718]]
# [array([[-0.00154179, -0.27406773,  0.09698609],
#         [-0.00104215, -0.27246043,  0.0919264 ],
#         [-0.00216231, -0.27137497,  0.0866614 ],
#         ...,
#         [-0.30914643,  0.13757195,  0.30538505],
#         [-0.30904537,  0.1399334 ,  0.30508766],
#         [-0.30734476,  0.14267413,  0.30945718]], dtype=float32)]

# %%
import polyscope as ps
 
# Initialize polyscope
ps.init()
 
### Register a point cloud
# `my_points` is a Nx3 numpy array
ps.register_point_cloud("my points", mat)
 
ps.show()
# Out:
# GLFW emitted error: X11: The DISPLAY environment variable is missing
# [polyscope]  [EXCEPTION] [polyscope] ERROR: Failed to initialize glfw
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 4
#       1 import polyscope as ps
#       3 # Initialize polyscope
# ----> 4 ps.init()
#       6 ### Register a point cloud
#       7 # `my_points` is a Nx3 numpy array
#       8 ps.register_point_cloud("my points", mat)
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/polyscope/core.py:14, in init(backend)
#      10 """Initialize Polyscope"""
#      12 cwd_before = os.getcwd() # see note below
# ---> 14 psb.init(backend)
#      16 # NOTE: For some reason I do not understand, calling psb.init() changes the working directory, causing e.g. writes to relative file paths to write to unexpected locations afterwards.
#      17 # As a simple workaround, we restore the CWD from before the call. Of course, this does not address the underlying cause, so there may be other subtle problems lurking.
#      18 os.chdir(cwd_before)
#
# RuntimeError: [polyscope]  [EXCEPTION] [polyscope] ERROR: Failed to initialize glfw
