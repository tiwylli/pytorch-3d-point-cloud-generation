# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
# %matplotlib ipympl

# %%
test = np.load('./data/03001627_inputRGB/1006be65e7bc937e9141f9b58470d646.npy') / 255.0
print(test.shape)
print(test[0].shape)
test_image = test[1]
# Out:
# (24, 64, 64, 3)
# (64, 64, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot()

plt.imshow(test_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#mat_import = scipy.io.loadmat("./data/03001627_depth/1006be65e7bc937e9141f9b58470d646.mat")
mat_import = scipy.io.loadmat("./data/03001627_depth/1006be65e7bc937e9141f9b58470d646.mat")

# %%
print(mat_import.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Z', 'trans'])

# %%
print(mat_import["Z"].shape)
# Out:
# (100, 128, 128)

# %%
print(mat_import["Z"][0].shape)
# Out:
# (128, 128)

# %%
mat = mat_import["Z"][1]
test_array= np.array(mat)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mat_import = scipy.io.loadmat("./results/ORIG_STG2_sgd_trueWD_adam_trueWD_1K/108238b535eb293cd79b19c7c4f0e293.mat")
#108238b535eb293cd79b19c7c4f0e293.mat ok
#1ac6531a337de85f2f7628d6bf38bcc4.mat yikes
#11e28120789c20abc8687ff9b0b4e4ac.mat perfect 
print(mat_import.keys())
print( "image shape " , mat_import["image"].shape)
print("image 0 shape " , mat_import["image"][0].shape)
print("pointcloud shape ",mat_import["pointcloud"].shape)

mat = mat_import["image"][0]
test_array= np.array(mat)

fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/ORIG_STG2_sgd_trueWD_adam_trueWD_1K/108238b535eb293cd79b19c7c4f0e293.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mat_import = scipy.io.loadmat("./results/ORIG_STG2_sgd_trueWD_adam_trueWD_1K/108238b535eb293cd79b19c7c4f0e293.mat")
#       2 #108238b535eb293cd79b19c7c4f0e293.mat ok
#       3 #1ac6531a337de85f2f7628d6bf38bcc4.mat yikes
#       4 #11e28120789c20abc8687ff9b0b4e4ac.mat perfect
#       5 print(mat_import.keys())
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:225, in loadmat(file_name, mdict, appendmat, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)
#     222     3.14159265+3.14159265j])
#     223 """
#     224 variable_names = kwargs.pop('variable_names', None)
# --> 225 with _open_file_context(file_name, appendmat) as f:
#     226     MR, _ = mat_reader_factory(f, **kwargs)
#     227     matfile_dict = MR.get_variables(variable_names)
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/ORIG_STG2_sgd_trueWD_adam_trueWD_1K/108238b535eb293cd79b19c7c4f0e293.mat'

# %%
print(mat_import["pointcloud"])
print(mat_import["pointcloud"].shape)

# %%
print(mat_import["pointcloud"][0].shape)
print(mat_import["pointcloud"][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(mat_import["pointcloud"][0].shape)
#       2 print(mat_import["pointcloud"][0])
#
# KeyError: 'pointcloud'

# %%
print(mat_import["pointcloud"][0][0].shape)
print(mat_import["pointcloud"][0][0])


mat = mat_import["pointcloud"][0]
print(mat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(mat_import["pointcloud"][0][0].shape)
#       2 print(mat_import["pointcloud"][0][0])
#       5 mat = mat_import["pointcloud"][0]
#
# KeyError: 'pointcloud'

# %%
import polyscope as ps
 
# Initialize polyscope
ps.init()
 
### Register a point cloud
# `my_points` is a Nx3 numpy array
ps.register_point_cloud("my points", mat)
 
ps.show()
# Out:
# GLFW emitted error: X11: The DISPLAY environment variable is missing
# [polyscope]  [EXCEPTION] [polyscope] ERROR: Failed to initialize glfw
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 4
#       1 import polyscope as ps
#       3 # Initialize polyscope
# ----> 4 ps.init()
#       6 ### Register a point cloud
#       7 # `my_points` is a Nx3 numpy array
#       8 ps.register_point_cloud("my points", mat)
#
# File ~/anaconda3/envs/pcg3/lib/python3.11/site-packages/polyscope/core.py:14, in init(backend)
#      10 """Initialize Polyscope"""
#      12 cwd_before = os.getcwd() # see note below
# ---> 14 psb.init(backend)
#      16 # NOTE: For some reason I do not understand, calling psb.init() changes the working directory, causing e.g. writes to relative file paths to write to unexpected locations afterwards.
#      17 # As a simple workaround, we restore the CWD from before the call. Of course, this does not address the underlying cause, so there may be other subtle problems lurking.
#      18 os.chdir(cwd_before)
#
# RuntimeError: [polyscope]  [EXCEPTION] [polyscope] ERROR: Failed to initialize glfw

# %%
#load an npy file
trans_fuse8 = np.load("./data/trans_fuse8.npy")
print(trans_fuse8)

# %%
mat_import = scipy.io.loadmat("./render/output/8_depth_fixed_mat/exr_77463.mat")
print(mat_import.keys())

mat = mat_import["image"][0]
test_array= np.array(mat)

fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)

# %%
mat_import = scipy.io.loadmat("./render/output/8_depth_fixed_mat/exr_100070.mat")
print(mat_import.keys())
print(mat_import["Z"].shape)
print(mat_import["Z"][0].shape)

mat = mat_import["Z"][2]
test_array = np.array(mat)
fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
