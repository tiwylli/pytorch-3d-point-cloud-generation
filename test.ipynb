# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
# %matplotlib ipympl

# %%
test = np.load('./data/test_image.npy') / 255.0
test.shape
test_image = test[1]

# %%
fig = plt.figure()
ax = fig.add_subplot()

plt.imshow(test_image, cmap='gray')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mat_import = scipy.io.loadmat("./data/test_depth_fixed.mat")

# %%
print(mat_import.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Z'])

# %%
print(mat_import["Z"].shape)
# Out:
# (8, 128, 128)

# %%
print(mat_import["Z"][0].shape)
# Out:
# (128, 128)

# %%
mat = mat_import["Z"][0]
test_array= np.array(mat)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# 
plt.imshow(test_array)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
